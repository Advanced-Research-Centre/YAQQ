# %%
# !pip install qiskit

# %%
# !pip install qiskit --upgrade
# Out:
# Collecting qiskit
#   Downloading qiskit-0.41.0.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting qiskit-terra==0.23.1
#   Downloading qiskit_terra-0.23.1-cp38-cp38-win_amd64.whl (4.6 MB)
#      ---------------------------------------- 4.6/4.6 MB 1.1 MB/s eta 0:00:00
# Collecting qiskit-aer==0.11.2
#   Downloading qiskit_aer-0.11.2-cp38-cp38-win_amd64.whl (9.6 MB)
#      ---------------------------------------- 9.6/9.6 MB 1.3 MB/s eta 0:00:00
# Collecting qiskit-ibmq-provider==0.20.0
#   Downloading qiskit_ibmq_provider-0.20.0-py3-none-any.whl (241 kB)
#      -------------------------------------- 241.3/241.3 kB 1.2 MB/s eta 0:00:00
# Collecting scipy>=1.0
#   Downloading scipy-1.10.0-cp38-cp38-win_amd64.whl (42.2 MB)
#      -------------------------------------- 42.2/42.2 MB 904.9 kB/s eta 0:00:00
# Collecting numpy>=1.16.3
#   Downloading numpy-1.24.2-cp38-cp38-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 1.3 MB/s eta 0:00:00
#   Downloading numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 1.2 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.0
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      -------------------------------------- 247.7/247.7 kB 1.2 MB/s eta 0:00:00
# Collecting websocket-client<=1.3.3
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      -------------------------------------- 54.3/54.3 kB 564.3 kB/s eta 0:00:00
# Collecting urllib3>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.6/140.6 kB 1.2 MB/s eta 0:00:00
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp38-cp38-win_amd64.whl (101 kB)
#      -------------------------------------- 101.4/101.4 kB 1.2 MB/s eta 0:00:00
# Collecting requests>=2.19
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.8/62.8 kB 848.1 kB/s eta 0:00:00
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.2.0-py3-none-any.whl (6.0 kB)
# Collecting dill>=0.3
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      -------------------------------------- 110.5/110.5 kB 1.1 MB/s eta 0:00:00
# Collecting rustworkx>=0.12.0
#   Downloading rustworkx-0.12.1-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.3 MB/s eta 0:00:00
# Collecting sympy>=1.3
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 1.5 MB/s eta 0:00:00
# Collecting ply>=3.10
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting stevedore>=3.0.0
#   Downloading stevedore-5.0.0-py3-none-any.whl (49 kB)
#      -------------------------------------- 49.6/49.6 kB 635.0 kB/s eta 0:00:00
# Collecting psutil>=5
#   Downloading psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
#      -------------------------------------- 252.5/252.5 kB 1.3 MB/s eta 0:00:00
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      -------------------------------------- 61.5/61.5 kB 470.6 kB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp38-cp38-win_amd64.whl (95 kB)
#      -------------------------------------- 95.8/95.8 kB 909.8 kB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ------------------------------------ 155.3/155.3 kB 775.5 kB/s eta 0:00:00
# Collecting cryptography>=1.3
#   Downloading cryptography-39.0.1-cp36-abi3-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.4 MB/s eta 0:00:00
# Collecting pyspnego>=0.1.6
#   Downloading pyspnego-0.8.0-cp38-cp38-win_amd64.whl (244 kB)
#      -------------------------------------- 245.0/245.0 kB 1.5 MB/s eta 0:00:00
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.7/112.7 kB 1.3 MB/s eta 0:00:00
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      -------------------------------------- 532.6/532.6 kB 1.3 MB/s eta 0:00:00
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-win_amd64.whl (178 kB)
#      -------------------------------------- 178.8/178.8 kB 1.2 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 118.7/118.7 kB 1.2 MB/s eta 0:00:00
# Building wheels for collected packages: qiskit
#   Building wheel for qiskit (setup.py): started
#   Building wheel for qiskit (setup.py): finished with status 'done'
#   Created wheel for qiskit: filename=qiskit-0.41.0-py3-none-any.whl size=12827 sha256=dfa409656ca428cf5ebe9f5bc5e1b5d34ac6133617b7138ebf2a25c1bc07f9bc
#   Stored in directory: c:\users\aritr\appdata\local\pip\cache\wheels\ae\b7\d8\fc6c031c3a4a12a26db0fb7cf23d7453a6c253265b062b5b4a
# Successfully built qiskit
# Installing collected packages: ply, mpmath, charset-normalizer, websockets, websocket-client, urllib3, sympy, six, pycparser, psutil, pbr, numpy, idna, dill, certifi, stevedore, scipy, rustworkx, requests, python-dateutil, cffi, qiskit-terra, cryptography, qiskit-aer, pyspnego, requests-ntlm, qiskit-ibmq-provider, qiskit
# Successfully installed certifi-2022.12.7 cffi-1.15.1 charset-normalizer-3.0.1 cryptography-39.0.1 dill-0.3.6 idna-3.4 mpmath-1.2.1 numpy-1.23.5 pbr-5.11.1 ply-3.11 psutil-5.9.4 pycparser-2.21 pyspnego-0.8.0 python-dateutil-2.8.2 qiskit-0.41.0 qiskit-aer-0.11.2 qiskit-ibmq-provider-0.20.0 qiskit-terra-0.23.1 requests-2.28.2 requests-ntlm-1.2.0 rustworkx-0.12.1 scipy-1.10.0 six-1.16.0 stevedore-5.0.0 sympy-1.11.1 urllib3-1.26.14 websocket-client-1.3.3 websockets-10.4

# %%
from qiskit.transpiler.passes.synthesis import SolovayKitaev
from qiskit.transpiler.passes import SolovayKitaevSynthesis, UnitarySynthesis
from qiskit.quantum_info import Operator
from qiskit import *
import numpy as np
from astropy.coordinates import cartesian_to_spherical
from qiskit import QuantumCircuit, Aer, transpile, assemble
from qiskit.circuit.library import TGate, HGate, TdgGate
import matplotlib.pyplot as plt
from qiskit.visualization import plot_bloch_multivector
from qiskit.quantum_info import state_fidelity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9f50090bb46d> in <module>
# ----> 1 from qiskit.transpiler.passes.synthesis import SolovayKitaev
#       2 from qiskit.transpiler.passes import SolovayKitaevSynthesis, UnitarySynthesis
#       3 from qiskit.quantum_info import Operator
#       4 from qiskit import *
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'qiskit'

# %%
def solovay_kiteav_decomposition(qc):
    """
    INPUT
    ------
    qc : QuantumCircuit
    
    OUTPUT
    ------
    tuple : (decomposed circuit, depth)
    """
    skd = SolovayKitaev(recursion_degree=3)
    dc = skd(qc)
    return dc, dc.depth()

# %%
plt.plot(ang_list, depth_list)

# %%
basis_gates = ['h', 't']
skd = UnitarySynthesis(method = 'sk', basis_gates = basis_gates, approximation_degree = 0.5, synth_gates = 'c')
dc = skd(c)
dc.draw()
# Out:
#    ┌───┐
# q: ┤ Y ├
#    └───┘

# %%
# ?UnitarySynthesis

# %%
c = QuantumCircuit(2)
c.y(0)
c.cx(0,1)
c.decompose(gates_to_decompose =[HGate(), TGate()]).draw()
# Out:
#      ┌───┐
# q_0: ┤ Y ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
sim = Aer.get_backend('statevector_simulator')
qc1 = QuantumCircuit(1)
qc2 = QuantumCircuit(1)
qc1.rz(0,0)
qc1_state = execute(qc1, sim).result().get_statevector(qc1)
qc2.rx(np.pi/2,0)
qc2_state = execute(qc2, sim).result().get_statevector(qc2)
fid = np.round(state_fidelity(qc1_state, qc2_state),3)

# %%
for ang in np.arange(0, 2*np.pi, np.pi/10):
    equi_qc = QuantumCircuit(1)
    equi_qc.ry(ang, 0)
    equi_qc_state = execute(equi_qc, sim).result().get_statevector(equi_qc)
    equi_fid_1 = np.round(state_fidelity(qc1_state, equi_qc_state),3)
    equi_fid_2 = np.round(state_fidelity(qc2_state, equi_qc_state),3)
#     if equi_fid_1 == fid and equi_fid_2 == fid:


plot_bloch_multivector(qc2_state)
# Out:
# (<Figure size 288x288 with 1 Axes>, <Figure size 288x288 with 1 Axes>)

# %%
# https://stackoverflow.com/questions/9600801/evenly-distributing-n-points-on-a-sphere
import math
def fibonacci_sphere(samples=1000):

    rz_angle,rx_angle, x_points, y_points, z_points  = [],[],[],[],[]
    phi = math.pi * (3. - math.sqrt(5.))  # golden angle in radians

    for i in range(samples):
        y = 1 - (i / float(samples - 1)) * 2  # y goes from 1 to -1
        radius = math.sqrt(1 - y * y)  # radius at y

        theta = phi * i  # golden angle increment

        x = math.cos(theta) * radius
        z = math.sin(theta) * radius

        x_points.append(x)
        y_points.append(y)
        z_points.append(z)
        sphe_coor = cartesian_to_spherical(x, y, z)
        rz_angle.append(sphe_coor[1].radian+np.pi/2)
        rx_angle.append(sphe_coor[2].radian)
    return rz_angle, rx_angle, x_points, y_points, z_points

# %%
fibonacci_sphere(4)
# Out:
# ([1.5707963267948966,
#   2.261212834529893,
#   0.3505060641227318,
#   1.5707963267948966],
#  [1.5707963267948966, 2.694495654559817, 4.95480345694593, 4.71238898038469],
#  [0.0, -0.695198045233462, 0.08242576373001424, 0.0],
#  [1.0, 0.33333333333333337, -0.33333333333333326, -1.0],
#  [0.0, 0.6368583569306933, -0.9391990642895748, 0.0])

# %%
import mpl_toolkits.mplot3d
points = 4
plt.figure().add_subplot(111, projection='3d').scatter(fibonacci_sphere(points)[2],
                                                       fibonacci_sphere(points)[3],
                                                      fibonacci_sphere(points)[4]);
plt.show()

# %%
rz_ang_list, rx_ang_list = fibonacci_sphere(4)[0], fibonacci_sphere(4)[1]
equiv_qc = QuantumCircuit(1)
equiv_qc.rz(rz_ang_list[0],0)
equiv_qc.rx(rx_ang_list[0],0)
qc1_state = execute(equiv_qc, sim).result().get_statevector(equiv_qc)
plot_bloch_multivector(qc1_state)

# %%
equiv_qc = QuantumCircuit(1)
equiv_qc.rz(rz_ang_list[1],0)
equiv_qc.rx(rx_ang_list[1],0)
qc1_state = execute(equiv_qc, sim).result().get_statevector(equiv_qc)
plot_bloch_multivector(qc1_state)

# %%
equiv_qc = QuantumCircuit(1)
equiv_qc.rz(rz_ang_list[2],0)
equiv_qc.rx(rx_ang_list[2],0)
qc1_state = execute(equiv_qc, sim).result().get_statevector(equiv_qc)
plot_bloch_multivector(qc1_state)

# %%
equiv_qc = QuantumCircuit(1)
equiv_qc.rz(rz_ang_list[3],0)
equiv_qc.rx(rx_ang_list[3],0)
qc1_state = execute(equiv_qc, sim).result().get_statevector(equiv_qc)
plot_bloch_multivector(qc1_state)

# %%
points = 200
rz_ang_list, rx_ang_list = fibonacci_sphere(points)[0], fibonacci_sphere(points)[1]

depth_list = []
for p in range(points):
    equiv_qc = QuantumCircuit(1)
    equiv_qc.rz(rz_ang_list[p],0)
    equiv_qc.rx(rx_ang_list[p],0)
    _, depth = solovay_kiteav_decomposition(equiv_qc)
#     print(depth)
    depth_list.append(depth)

# %%
plt.semilogy(depth_list)
plt.xlabel('No. of equidistant states')
plt.ylabel('Depth after Decomposition')
plt.savefig('equidistant_state_depth.png')
